# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from plots import plot_SH, plot_exp_sin, plot_tex


# %load_ext autoreload
# %autoreload 2
# Out:
# c:\Users\Bruker\anaconda3\envs\SAXSTT\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fig = plt.figure(figsize=plt.figaspect(1.))
ax = fig.add_subplot(projection='3d')
l, m = 4, 0
plot_SH(ax, l, m)
plt.savefig('Y{}_{}.svg'.format(l, m), format='svg')
plt.show()

# %%
ls = np.arange(0,7,2) # l=  0, 2, 4, 6
figsize_px, DPI = 300, 400
figsize_in = figsize_px / DPI
fig = plt.figure(figsize=(12, 2), dpi=DPI)
spec = gridspec.GridSpec(ncols=2*ls[-1]+1, nrows=1, figure=fig)
for i, l in enumerate(ls):
    ax = fig.add_subplot(spec[0, i], projection='3d')
    plot_SH(ax, l)
#plt.tight_layout()
plt.savefig('sph_harm_samples.svg', format='svg')
#plt.text(x=1200,y=1,s="Spherical Harmonics")
plt.show()

# %%
fig = plt.figure(figsize=plt.figaspect(1.))
ax = fig.add_subplot(projection='3d')
A, B = 1, 0.5
plot_exp_sin(ax, A, B)
plt.savefig('F{}_{}.svg'.format(A, B), format='svg')
plt.show()

# %%
ls = np.arange(2,15,4) # l=  0, 2, 4, 6
figsize_px, DPI = 800, 300
figsize_in = figsize_px / DPI
fig = plt.figure(figsize=(36, 12), dpi=DPI)
spec = gridspec.GridSpec(ncols=2*ls[-1]+1, nrows=1, figure=fig)
for i, l in enumerate(ls):
    ax = fig.add_subplot(spec[0, i], projection='3d')
    plot_exp_sin(ax, A=1, B = l)
#plt.tight_layout()
plt.savefig('exp_sin_samples.svg', format='svg')
#plt.text(x=1200,y=1,s="Spherical Harmonics")
plt.show()

# %%
plot_tex()
# Out:
# c:\Users\Bruker\anaconda3\envs\SAXSTT\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.canvas.print_figure(bytes_io, **kw)
