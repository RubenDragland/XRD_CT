# %%
import numpy as np

from skimage.transform import radon, rescale
from skimage import data

# %%
from skimage.data import shepp_logan_phantom
from skimage.transform import radon, rescale
import matplotlib.pyplot as plt
import imageio

image = shepp_logan_phantom()
image = rescale(image, scale=0.4, mode='reflect', channel_axis=None)
image = imageio.imread('img_0147.png')
image = rescale(image, scale=0.4, mode='reflect', channel_axis=None)



fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4.5))

ax1.set_title("Original")
ax1.imshow(image, cmap=plt.cm.Greys_r)

theta = np.linspace(0., 180., max(image.shape), endpoint=False)
sinogram = radon(image, theta=theta)
dx, dy = 0.5 * 180.0 / max(image.shape), 0.5 / sinogram.shape[0]
ax2.set_title("Radon transform\n(Sinogram)")
ax2.set_xlabel("Projection angle (deg)")
ax2.set_ylabel("Projection position (pixels)")
ax2.imshow(sinogram, cmap=plt.cm.Greys_r,
           extent=(-dx, 180.0 + dx, -dy, sinogram.shape[0] + dy),
           aspect='auto')

fig.tight_layout()
plt.show()
# Out:
# C:\Users\Bruker\AppData\Local\Temp\ipykernel_42332\1208806875.py:8: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('img_0147.png')
# C:\Users\Bruker\AppData\Local\Temp\ipykernel_42332\1208806875.py:28: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()

# %%
from plots import plot_sinogram

# %load_ext autoreload
# %autoreload 2

image = imageio.imread('img_0147.png')
image = rescale(image, scale=0.4, mode='reflect', channel_axis=None)

plot_sinogram(image)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Users\Bruker\AppData\Local\Temp\ipykernel_42332\4037594293.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('img_0147.png')
# c:\Users\Bruker\anaconda3\envs\SAXSTT\lib\site-packages\skimage\transform\radon_transform.py:75: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn('Radon transform: image must be zero outside the '
