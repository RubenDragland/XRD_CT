# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib
# %reload_ext autoreload
# %autoreload 2

# %%
symbolic_data = scipy.io.loadmat('result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_symbolic.mat')
print(symbolic_data.keys())
symbolic_mask = symbolic_data["s"]["mask3D"][0,0]
symbolic_theta = symbolic_data["s"]["theta"][0,0][0,0][0]
symbolic_phi = symbolic_data["s"]["phi"][0,0][0,0][0]
symbolic_a = symbolic_data["s"]["a"][0,0][:,3][0]

# Idea: Make class to represent the sample. Make things nicer to work with. Save processed data to file etc.


automatic_data = scipy.io.loadmat('result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_AD.mat')
automatic_mask = automatic_data["s"]["mask3D"][0,0]
automatic_theta = automatic_data["s"]["theta"][0,0][0,0][0]
automatic_phi = automatic_data["s"]["phi"][0,0][0,0][0]
automatic_a = automatic_data["s"]["a"][0,0][0,0][0][0]

semi_data = scipy.io.loadmat('result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_sym0_AD.mat')
semi_mask = semi_data["s"]["mask3D"][0,0]
semi_theta = semi_data["s"]["theta"][0,0][0,0][0]
semi_phi = semi_data["s"]["phi"][0,0][0,0][0]
semi_a = semi_data["s"]["a"][0,0][0,0][0]

symbolic_a
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'p', 's', 'timing', 'e', '__function_workspace__'])
# (array([[[-1.00000000e-04,  8.84491289e-01, -2.07019026e+01,
#          -1.00000000e-04],
#         [ 8.26799111e-02,  6.64196230e-01, -1.51143065e+00,
#          -8.21874442e-01],
#         [ 3.56249487e+00, -2.70796236e-02, -8.75027369e-02,
#           6.42556019e+00],
#         [-1.00000000e-04, -2.31865879e+00, -5.43161573e-01,
#          -1.00000000e-04]],
#
#        [[-1.00000000e-04, -1.23519934e+01, -2.32943611e-01,
#           4.03292040e-01],
#         [-1.00000000e-04, -5.67882984e-02,  1.69258186e-01,
#          -1.74474857e+00],
#         [-5.73509116e-01, -4.37862915e-02, -6.88742862e-03,
#          -5.71011600e-01],
#         [-7.73762867e-01, -1.18990236e+00, -3.37947804e-02,
#          -1.35210271e+00]],
#
#        [[-1.00000000e-04,  2.34167448e-01, -8.36087029e-01,
#          -1.75887609e-02],
#         [-1.00000000e-04, -2.26891977e-02,  4.87757247e-02,
# ...

# %%
#%matplotlib ipympl
# fig, ax = plt.subplots(1,3, figsize=(15,5))
# ax[0].imshow(symbolic_mask[0,:,:])
# ax[1].imshow(symbolic_mask[:,0,:])
# ax[2].imshow(symbolic_mask[:,:,0])
# plt.show()
fig = plt.figure()
ax = fig.add_subplot(131, projection='3d')
ax.voxels(symbolic_mask, edgecolor="k")
ax1 = fig.add_subplot(132, projection='3d')
ax1.voxels(automatic_mask, edgecolor="k")
ax2 = fig.add_subplot(133, projection='3d')
ax2.voxels(semi_mask, edgecolor="k")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = np.arange(0, len(np.ndarray.flatten(symbolic_mask)))
fig, ax = plt.subplots(1,1, figsize=(15,5))
ax.bar(x-0.25,np.ndarray.flatten(symbolic_theta) * np.ndarray.flatten(symbolic_mask), width=0.5)
ax.bar(x+0.25,np.ndarray.flatten(symbolic_phi)* np.ndarray.flatten(symbolic_mask), width=0.5)
plt.show()

# %%
import sys

sys.path.append(r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Plotting") #\plots.py")
from plots import *
# Out:
# c:\Users\Bruker\anaconda3\envs\SAXSTT\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from post_processing_class import TensorTomographyReconstruction

tt_AD = TensorTomographyReconstruction("result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_AD_onesmask.mat")
tt_S = TensorTomographyReconstruction("result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_symbolic_onesmask.mat")

# %matplotlib qt
plot_result_heatmap(tt_AD, tt_S, "Debugging Result 64 Voxels")
# Out:
# (4, 64)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Results\post_processing.ipynb Cell 6 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Bruker/OneDrive/Dokumenter/NTNU/XRD_CT/Results/post_processing.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> tt_S = TensorTomographyReconstruction("result_SASTT_carbon_knot_aligned_ASTRA_correctedny4nx4_q17-40_all_again_symbolic_onesmask.mat")
#       <a href='vscode-notebook-cell:/c%3A/Users/Bruker/OneDrive/Dokumenter/NTNU/XRD_CT/Results/post_processing.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> get_ipython().run_line_magic('matplotlib', 'qt')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Bruker/OneDrive/Dokumenter/NTNU/XRD_CT/Results/post_processing.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> plot_result_heatmap(tt_AD, tt_S, "Debugging Result 64 Voxels")
#
# ...
