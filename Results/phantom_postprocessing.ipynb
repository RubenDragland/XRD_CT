# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib

import sys

sys.path.append(r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Plotting") #\plots.py")
from plots import *
from post_processing_class import TensorTomographyReconstruction

# %reload_ext autoreload
# %autoreload 2

# %%
res_path_no_filter = r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Data sets\analysis\SASTT\SASTT_test_phantom_7Nov2022_vert_scat_aligned_ASTRA\SH\results\result_SASTT_test_phantom_7Nov2022_vert_scat_aligned_ASTRA_q17-40_all_again_symbolic.mat"
res_phantom_no_filter = TensorTomographyReconstruction(res_path_no_filter, dataset=False)

# %%
a0 = res_phantom_no_filter.flatten("a6")

print(res_phantom_no_filter.error_data[-1])
filtered_a0 = a0[~np.isclose(a0, np.zeros(a0.shape), rtol= 1e-4)]

len(filtered_a0)
plt.hist(a0)
plt.show()
colormap_a0 = res_phantom_no_filter["phi"]

plt.imshow(colormap_a0[15,:,:])
plt.colorbar()
# Out:
# [0.03717602]

# %%
phi = res_phantom_no_filter.flatten("a0")
plt.hist(phi, range=(0.9,1.1))
plt.hist(np.ones(10))
# Out:
# (array([ 0.,  0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <BarContainer object of 10 artists>)

# %%
another_test_path = r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Data sets\analysis\SASTT\Synthetic_sample_ny4_ny4_all_coeffs\SH\results\result_Synthetic_sample_ny4_ny4_all_coeffs_q17-40_all_again_.mat"
instance = TensorTomographyReconstruction(another_test_path)

# %%
attr = instance.flatten("a0")
plt.hist(attr)
# Out:
# (array([ 4.,  6.,  6.,  7., 12.,  5.,  6., 10.,  4.,  4.]),
#  array([0.51298868, 0.54482321, 0.57665774, 0.60849227, 0.64032679,
#         0.67216132, 0.70399585, 0.73583038, 0.76766491, 0.79949944,
#         0.83133397]),
#  <BarContainer object of 10 artists>)

# %%
symsaxs = scipy.io.loadmat(r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Data sets\analysis\SASTT\SASTT_test_phantom_7Nov2022_vert_scat_aligned_ASTRA\SH\optimization_output\current_opt_symsaxs.mat")

# %%
symsaxs.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'grad_a', 'e', 'a_tomo'])

# %%
plt.imshow(symsaxs["a_tomo"][:,:,15])
plt.colorbar()
plt.show()
plt.imshow(symsaxs["a_tomo"][15,:,:])
plt.colorbar()
plt.show()
plt.imshow(symsaxs["a_tomo"][:,15,:])
plt.colorbar()
plt.show()

# %%
plt.hist(np.ndarray.flatten(symsaxs["a_tomo"][11:19,11:19,11:19]) )
# Out:
# (array([ 95.,  36.,  38.,  12.,  43.,  32., 109., 103.,  12.,  32.]),
#  array([0.00654461, 0.1668328 , 0.32712098, 0.48740917, 0.64769736,
#         0.80798555, 0.96827374, 1.12856193, 1.28885012, 1.44913831,
#         1.60942649]),
#  <BarContainer object of 10 artists>)

# %%
saxs_angles = scipy.io.loadmat(r"C:\Users\Bruker\OneDrive\Dokumenter\NTNU\XRD_CT\Data sets\analysis\SASTT\SASTT_test_phantom_7Nov2022_vert_scat_aligned_ASTRA\SH\optimization_output\current_opt_saxs_angle.mat")
saxs_theta = np.reshape(saxs_angles["phi_struct"], (30,30,30))

# %%
plt.imshow(saxs_theta[:,:,15])
plt.colorbar()
plt.show()
plt.imshow(saxs_theta[15,:,:])
plt.colorbar()
plt.show()
plt.imshow(saxs_theta[:,15,:])
plt.colorbar()
plt.show()

print(saxs_theta[:,:,15])
# Out:
# [[7.85399788e-01 7.85400320e-01 7.85399460e-01 7.85398901e-01
#   7.85398542e-01 7.85398274e-01 7.85398188e-01 7.85398171e-01
#   7.85398159e-01 7.85398160e-01 7.85398163e-01 7.85398163e-01
#   7.85398163e-01 7.85398163e-01 7.85398163e-01 7.85398163e-01
#   7.85398163e-01 7.85398163e-01 7.85398163e-01 7.85398163e-01
#   7.85398111e-01 7.85398162e-01 7.85398136e-01 7.85398125e-01
#   7.85398095e-01 7.85397991e-01 7.85398019e-01 7.85398225e-01
#   7.85398991e-01 7.85399139e-01]
#  [7.85402501e-01 7.85403585e-01 7.85399666e-01 7.85398665e-01
#   7.85398429e-01 7.85398357e-01 7.85398235e-01 7.85398179e-01
#   7.85398170e-01 7.85398163e-01 7.85398163e-01 7.85398163e-01
#   7.85398163e-01 7.85398163e-01 7.85398163e-01 7.85398163e-01
#   7.85398163e-01 7.85398163e-01 7.85398163e-01 7.85398163e-01
#   7.85398161e-01 7.85398146e-01 7.85398128e-01 7.85398105e-01
#   7.85398073e-01 7.85398058e-01 7.85398085e-01 7.85398161e-01
#   7.85399960e-01 7.85401081e-01]
# ...
